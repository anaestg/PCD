# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/anaestg">
# <img src="https://avatars.githubusercontent.com/u/100564768?s=400&u=6113bcf4824e38922c0cfa7ea33de2cc1833f7d1&v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Ana Esteban González 22124326">
# <a href ="https://github.com/anaestg?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# # Prueba de que mi pc es una mie... ?

# %% [markdown]
# # Before

# %%
from IPython import display as dp

# %%
dp.Image("Imagenes/CoresBefore.png")

# %% [markdown]
# # After

# %%
dp.Image("Imagenes/CoresAfter.png")

# %%
def fib(n):
    if n in {0, 1}:
        return 1
    else:
        return(fib(n - 1) + fib(n - 2))

# %%
fib(30)
# Out:
# 1346269

# %%
fib(70)

# %%
import multiprocessing as mp, threading as th

# %%
th.active_count()
# Out:
# 7

# %%
th.enumerate()
# Out:
# [<_MainThread(MainThread, started 2756)>,
#  <Thread(IOPub, started daemon 11244)>,
#  <Heartbeat(Heartbeat, started daemon 11644)>,
#  <ControlThread(Control, started daemon 772)>,
#  <HistorySavingThread(IPythonHistorySavingThread, started 16760)>,
#  <ParentPollerWindows(Thread-4, started daemon 9944)>,
#  <GarbageCollectorThread(Thread-5, started daemon 1780)>]
