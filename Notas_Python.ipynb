# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/anaestg">
# <img src="https://avatars.githubusercontent.com/u/100564768?s=400&u=6113bcf4824e38922c0cfa7ea33de2cc1833f7d1&v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Ana Esteban González 22124326">
# <a href ="https://github.com/anaestg?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %%
from IPython import display

# %% [markdown]
# # Indentation
# Indentation refers to the spaces at the beginning of a code line
#
# Where in other programming languages the indentation in code is for readability only, the indentation in Python is very important.
# Python uses indentation to indicate a block of code
#
# Python will give you an error if you skip the indentation

# %%
display.Image("Imagenes/ExampleIndentation.png")

# %% [markdown]
# # Creating a comment
# Comments start with a #, and Python will ignore them

# %%
display.Image("Imagenes/ExampleComment.png")

# %% [markdown]
# # Conditions and If Statements

# %%
display.Image("Imagenes/ExampleIf.png")

# %% [markdown]
# # The while Loop
# With the while loop we can execute a set of statements as long as a condition is true

# %%
display.Image("Imagenes/ExampleWhile.png")

# %% [markdown]
# # For loop
# A for loop is used for itering over a sequence (that is either a list, a set or a string)
#
# This is less like the for keyword in other programming languages, and works more like an iterator method as found in other object-orientated programming
#
# With the for loop we can execute a set of statementes, once for each item in a list, set...

# %%
display.Image("Imagenes/ExampleFor.png")

# %% [markdown]
# # Creating a Function
# In Python a function is defined using the def keyword

# %%
display.Image("Imagenes/ExampleFunction.png")

# %% [markdown]
# # Arrays Methods

# %%
display.Image("Imagenes/ExampleArrayMethods.png")
