# %% [markdown]
# <!-- PROFILE LINK -->
#
# <h1 style = "text-align:center; font-size: 30px">PROGRAMACIÓN CONCURRENTE Y DISTRIBUIDA</h1>
# <a href ="https://github.com/anaestg">
# <img src="https://avatars.githubusercontent.com/u/100564768?s=400&u=6113bcf4824e38922c0cfa7ea33de2cc1833f7d1&v=4" style="float:left;vertical-align:centre" width="110" height="110" title = "Ana Esteban González 22124326">
# <a href ="https://github.com/anaestg?tab=repositories">
# <img src="https://media-exp1.licdn.com/dms/image/C4D0BAQEu_Aa76fcmPw/company-logo_200_200/0/1630998679429?e=2159024400&v=beta&t=2feC9GG7RWCWizTqsK5HzDWB1TL2DOQuAVwnMf6FFvk" title = "M41" alt="UE" width="110" height="110" style="float:right;vertical-align:centre">

# %% [markdown]
# Nombre: Ana Esteban González

# %%
from IPython import display

# %% [markdown]
# ## Puerto es últimos 5 dígitos de su número de expediente

# %%
display.Image("Puerto_Expediente.png")

# %% [markdown]
# ## 6 Clientes Instanciados

# %%
display.Image("6Clientes.png")

# %% [markdown]
# Como se ve en la pantalla azul oscuro de la esquina superior derecha, el usuario debe introducir la ip y el puerto
# Tambien debe introducir un nickname que en este caso es el correo de la universidad

# %% [markdown]
# # Lista de Usuarios

# %%
display.Image("ListaUsuarios.png")

# %% [markdown]
# Los nicknames solo se enseñaban si tenian un caracter al principio, y si no tenian caracteres especiales. Así que he usado el número de expediente en vez del correo

# %% [markdown]
# ## Historial de chat almacenado en un archivo

# %%
display.Image("Historial_Chat.png")

# %% [markdown]
# # CÓDIGO

# %% [markdown]
# ## Código Servidor

# %%
display.Image("ServidorCodigo.png")

# %%
display.Image("ServidorCodigo2.png")

# %% [markdown]
# ## Código Cliente

# %%
display.Image("ClienteCodigo.png")
